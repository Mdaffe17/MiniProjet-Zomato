# %% [markdown]
# ## Application Streamlit
# En raison de la taille du dataset original (≈574 MB), une version échantillonnée
# du jeu de données a été utilisée pour le déploiement de l’application Streamlit.
# Les analyses complètes ont été réalisées localement sur l’ensemble du dataset.
# Impossible à pusher sur github avec un fichier aussi conséquent.
#
# Donc j'ai décidé de faire un échantillon pour pouvoir déployer sur Streamlit.

# %%
import pandas as pd

df = pd.read_csv("../data/zomato.csv", encoding="latin-1")

df_sample = df.sample(n=3000, random_state=42)

df_sample.to_csv("../data/zomato_sample.csv", index=False)
